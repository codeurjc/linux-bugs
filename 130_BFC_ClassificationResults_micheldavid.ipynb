# %%
import pandas as pd
import numpy as npa
import math
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import cohen_kappa_score
warnings.simplefilter(action='ignore', category=UserWarning)
from IPython.display import display, HTML
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows',None)

# %%
david_results = pd.read_csv('130_results_david.csv').to_dict('records')
michel_results = pd.read_csv('130_results_michel.csv').to_dict('records')

# %%
david_results_map = {element['commit_hash']: element for element in david_results }
michel_results_map = {element['commit_hash']: element for element in michel_results }

# %%
def sameResult(r1,r2):
    if r1 == r2: return True
    if r1 == 'none': 
        if r2 == 'unknown': return True
    if r1 == 'unknown': 
        if r2 == 'none': return True
    return False

# %%
categories = {
    "Timing and execution": 0,
    "Exchange of Information": 1,
    "Memory": 2,
    "unknown": 3
}

# %%
same_is_bug_fixing_commit = 0
is_bug_fixing_commit_conflict = []
both_is_bug_fixing_commit = 0

same_is_safety_related = 0
is_safety_related_conflict = []
both_is_safety_related = 0

same_type_of_safety_related = 0
type_of_safety_related_conflict = []

kappa_cohen_results = {
    'is_bug_fixing_commit': { 'Michel': [], 'david': [] },
    'is_safety_related': { 'Michel': [], 'david': [] },
    'type_of_safety_related': { 'Michel': [], 'david': [] }
}

for m_result in michel_results:
    d_result = david_results_map[m_result['commit_hash']]

    kappa_cohen_results['is_bug_fixing_commit']['Michel'].append(1 if m_result['is_bug_fixing_commit'] else 0)
    kappa_cohen_results['is_bug_fixing_commit']['david'].append(1 if d_result['is_bug_fixing_commit'] else 0)
    
    # IS BUG-FIXING COMMIT
    if d_result['is_bug_fixing_commit'] == m_result['is_bug_fixing_commit']:
        same_is_bug_fixing_commit += 1
    else:
        is_bug_fixing_commit_conflict.append(
            (d_result['is_bug_fixing_commit'],d_result['comment'],m_result['is_bug_fixing_commit'], m_result['comment'])
        )

    # CASES WHERE BOTH AGREE ON "IS BUG-FIXING COMMIT"
    if d_result['is_bug_fixing_commit'] and m_result['is_bug_fixing_commit']:

        both_is_bug_fixing_commit+=1
        
        kappa_cohen_results['is_safety_related']['Michel'].append(
            1 if m_result['is_safety_related'] == 'true' else 0 if m_result['is_safety_related'] == 'false' else 2
        )
        kappa_cohen_results['is_safety_related']['david'].append(
            1 if d_result['is_safety_related'] == 'true' else 0 if d_result['is_safety_related'] == 'false' else 2
        )  
        
        # IS SAFETY-RELATED BUG
        if d_result['is_safety_related'] == m_result['is_safety_related']:
            same_is_safety_related += 1

            # CASES WHERE BOTH AGREE ON "SAFETY-RELATED BUG"
            if d_result['is_safety_related'] == 'true' and m_result['is_safety_related'] == 'true':
                both_is_safety_related += 1
                
                kappa_cohen_results['type_of_safety_related']['Michel'].append(categories[m_result['type_of_safety_related']])                
                kappa_cohen_results['type_of_safety_related']['david'].append(categories[d_result['type_of_safety_related']])
                
                # SAFETY-RELATED BUG CATEGORY
                if d_result['type_of_safety_related'] == m_result['type_of_safety_related']:
                    same_type_of_safety_related += 1
                else:
                    type_of_safety_related_conflict.append(
                        (d_result['type_of_safety_related'], d_result['comment'], m_result['type_of_safety_related'], m_result['comment'])
                    )
        
        else:
            is_safety_related_conflict.append(
                (d_result['is_safety_related'], d_result['comment'], m_result['is_safety_related'], m_result['comment'])
            )

print("same_is_bug_fixing_commit: ", same_is_bug_fixing_commit, "/", len(michel_results), "(%.2f)"%(same_is_bug_fixing_commit*100/len(michel_results)))
print("same_is_safety_related: ", same_is_safety_related, "/", both_is_bug_fixing_commit, "(%.2f)"%(same_is_safety_related*100/both_is_bug_fixing_commit))
print("same_type_of_safety_related: ", same_type_of_safety_related, "/", both_is_safety_related, "(%.2f)"%(same_type_of_safety_related*100/both_is_safety_related))
# Out:
# same_is_bug_fixing_commit:  115 / 130 (88.46)
# same_is_safety_related:  23 / 41 (56.10)
# same_type_of_safety_related:  10 / 11 (90.91)

# %%
cohen_kappa_score(kappa_cohen_results['is_bug_fixing_commit']['Michel'], kappa_cohen_results['is_bug_fixing_commit']['david'])
# Out:
# 0.7540983606557377

# %%
cohen_kappa_score(kappa_cohen_results['is_safety_related']['Michel'], kappa_cohen_results['is_safety_related']['david'])
# Out:
# 0.3004739336492891

# %%
cohen_kappa_score(kappa_cohen_results['type_of_safety_related']['Michel'], kappa_cohen_results['type_of_safety_related']['david'])
# Out:
# 0.8405797101449275

# %% [markdown]
# ### Not same "Is a bug-fixing commit" reasoning

# %%
pd.DataFrame(is_bug_fixing_commit_conflict, columns =['david result', 'david comment', 'Michel result', 'Michel comment'])
# Out:
#     david result  \
# 0           True
# 1           True
# 2           True
# 3          False
# 4           True
# 5           True
# 6           True
# 7           True
# 8          False
# 9           True
# 10          True
# 11         False
# 12          True
# 13          True
# 14         False
#
#                                                                                                                                david comment  \
# 0                                                                                            Initialization of a variable to 0; due to a bug
# 1                                                                                                     Fixing a warning; possible future bug.
# 2                                               It explains the behaviour of the bug and possible future consequences; and also it fixes it.
# 3                                                                                       It seems that they are refactoring more than fixing.
# 4                 I would say that this commit is fixing a bug about a GPU error when initialization; maybe is considered as safety related.
# 5   They are fixing with this pull a livepatch bug; could be considered as safety related commit because it fixes an init fail of Livepatch.
# 6   They are fixing with this pull a livepatch bug; could be considered as safety related commit because it fixes an init fail of Livepatch.
# 7                                                                                             It is fixing a bug; but not related to safety.
# 8                                                                                       It is a perfomance feature; in my opinion (I think).
# 9                                                      It is fixing a bug realted to the type of an offset; but I'm not sure about the type.
# 10                                                                                          It is a bug; but related to some info messagese.
# 11                                                                                                    For me; it is a refactor or a feature.
# 12                                                                                            Looks like a fix; but not sure about the type.
# 13                                                                                                   They are preventing future bugs/issues.
# 14             After reading the mesage; I can conclude that the commit is not fixing a bug; it is refactoring and adding support (feature).
#
#     Michel result  \
# 0           False
# 1           False
# 2           False
# 3            True
# 4           False
# 5           False
# 6           False
# 7           False
# 8            True
# 9           False
# 10          False
# 11           True
# 12          False
# 13          False
# 14           True
#
#                                                                                                                                                      Michel comment
# 0                                                                                                       It seems to simply change how files/functions are displayed
# 1                                                                                                                Considered a fix but really just avoids a warning.
# 2                                         A condition is extended to cover only the necessary cases (and a section of code is not executed if it is not necessary).
# 3                                                                                                        Indicated as a "Correct" but i didnt understand the change
# 4                       It appears to fix a change introduced earlier; in this case to supplement a case not contemplated. I am not sure to what extent it is a fix
# 5                                                                                                                                          Does not look like a fix
# 6                                                                                                               It only adds a description to a parameter (comment)
# 7                                                                                                              Fixed a bug in the comprehension of some components
# 8                                                                                                                                Seems to fix a performance problem
# 9                                                                                                                     I'm not sure; it doesn't look like a bug-fix.
# 10                            It seems that it tries to give a warning instead of an error for a certain bug. It is not clear to me that it actually fixes the bug.
# 11  It seems that it was introduced as a condition that a controller had to have read/write permissions when it really only needed to have at least one of the two.
# 12                                                                                               Maybe is a fix; maybe not. Just extend a check for a specific case
# 13                                                                                                                                           Remove unnecesary code
# 14                                                                                          Many changes on the PR, i see some fix on them, but hard to identify it

# %% [markdown]
# ### Not same "Is a safety-related bug" reasoning

# %%
pd.DataFrame(is_safety_related_conflict, columns =['david result', 'david comment', 'Michel result', 'Michel comment'])
# Out:
#    david result  \
# 0       unknown
# 1       unknown
# 2          true
# 3          true
# 4          true
# 5          true
# 6       unknown
# 7         false
# 8       unknown
# 9          true
# 10      unknown
# 11      unknown
# 12      unknown
# 13      unknown
# 14        false
# 15         true
# 16         true
# 17      unknown
#
#                                                                                                                                                             david comment  \
# 0                                                                                                                         Initialization of a variable to 0; due to a bug
# 1                                                                                                              It is fixing a bug; but I don't know if it safety related.
# 2                                                             In this commit; they talk about fixing; and inside the message they specify some changes related to memory.
# 3                                                                                                                                       Fixing a bug realted to pointers.
# 4                                                                                               Fixing a bug related to the clock sequence; causing a reset on the board.
# 5                                                                                     It is a bug fixing commit about a pointer that was not pointing to the right clock.
# 6                                                                                                                    It clearly fixes a bug; but not sure about the type.
# 7                                                                                                      Fixes a bug; for me is not a safety bug and is not obvious either.
# 8                                                                                                It fixes two bugs in a build process; not sure if its related to safety.
# 9                                  It seems a safety bug related to keyctl (a command for working with keys from userspace); so for me is an exchange of information bug.
# 10                                                                               It seems a bug fixing related to a case specific; but not enough information to be sure.
# 11                                                                                                                                The message explains that it fixes bug.
# 12  This commit is about fixing a problem with memory blocks register into group list; I don't know if it that important to consider it safety; but is related to memory.
# 13                                                                                   I don't know if this bug fix about not returning negative codes could affect safety.
# 14                                                                                               It is not a safety bug because it adds a warning; but it is still a bug.
# 15                                                                                                                               Memory bug that is fixed in this commit.
# 16                                                                                                   It is fixing commit of a driver that hangs in an specific situation.
# 17                                                                                                                              It is a fix; but not sure about the type.
#
#    Michel result  \
# 0          false
# 1           true
# 2        unknown
# 3        unknown
# 4        unknown
# 5        unknown
# 6          false
# 7        unknown
# 8          false
# 9          false
# 10         false
# 11         false
# 12         false
# 13         false
# 14       unknown
# 15       unknown
# 16       unknown
# 17         false
#
#                                                                                                                                                                                                  Michel comment
# 0                                                                                                         Check that is a BFC after checking mail list. A variable is not initialize but returned in some cases
# 1                                                                                                                                                            Looks like a fix on bus ¿maybe a safety-relelated?
# 2                                                                                            There are too many changes in this merge. It seems to include some fixes but each one may be completely different.
# 3                                                                                                                                                                                            A fix to avoid NPE
# 4                                                                                                                                                           Looks like a fix; but I don't udestand the the func
# 5                                                                                                                                                                                                  Fix a clock
# 6                                                                                                                                      It is a change that tries to include some cases not contemplated so far.
# 7                                                                                                                                                     Looks like a fix; but I don't understand exactly the code
# 8   This merge include 2 changes that looks like a fix. Add a condition to check that CONFIG_PPC_64S_HASH_MMU is set so don't trigger a build failure. I think that a build failure is not a Safety-Related Bug
# 9                                                                                                                                                                               A parameter validation is fixed
# 10                                                                    From the message, it does not look like a fix. However; it is indicated that it is with the Fixes field. A condition is added in the code
# 11                                                                                                                                                                        It seems to indicate that it is a fix
# 12                                                                                         Fixes a bug that prevents memory from being added to a group list when the record for that block has actually failed
# 13                                                                                                                                       Negative return error codes are added; as it seems to solve a problem.
# 14                                                                                                                                                      A division that could have a denominator of 0 is fixed.
# 15                                                                                                                                                                         Ensures that a memory release occurs
# 16                                                                                                 It looks like a fix; it tries to fix that a driver does not restart because a variable is not set correctly.
# 17                                                                                                               Looking at the comment, this commit include 2 fixes, but I don't undestand how dts files works

# %% [markdown]
# ### Not same "Safety-related bug category" reasoning

# %%
pd.DataFrame(type_of_safety_related_conflict, columns =['david result', 'david comment', 'Michel result', 'Michel comment'])
# Out:
#   david result                                      david comment  \
# 0      unknown  Fixing a bug when about MPC that hang the system.
#
#           Michel result                                     Michel comment
# 0  Timing and execution  Reversed a change that caused the program to hang
